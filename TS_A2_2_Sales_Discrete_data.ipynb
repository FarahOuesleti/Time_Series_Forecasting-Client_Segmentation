# %% [markdown]
# # **Coffee and restaurant Sales Predictions**

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
import pandas as pd
import json
import ast

# %%
do = pd.read_excel("/content/Clean_Discrete_Drinks_1.xlsx")

# %% [markdown]
# # **Visualize Time series**

# %% [markdown]
# **Prepare data**

# %%
Sales_Drinkss = do[['Converted_Date', 'Sum_Revenues']].set_index(['Converted_Date'])

# %%
plt.figure(figsize=(20,6))
plt.plot(Sales_Drinkss)
plt.title("Drinks' Sales")
# Out:
# Text(0.5, 1.0, "Drinks' Sales")

# %% [markdown]
# ==> The newly generated dataset post discretisation is unusable for making predictions.
# Further analysis is present in the report.
